# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
import pandas as pd
from matplotlib import pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set()



xdf1 = pd.read_excel('xdata1.xlsx')
xdf2 = pd.read_excel('xdata2.xlsx')
ydf1 = pd.read_excel('ydata1.xlsx')
ydf2 = pd.read_excel('ydata2.xlsx')

xts1 = xdf1['#data']
yts1 = ydf1['#data']
xts2 = xdf2['#data']
yts2 = ydf2['#data']

xdf3 = pd.read_excel('xdata3.xlsx')
xdf4 = pd.read_excel('xdata4.xlsx')
xdf5 = pd.read_excel('xdata5.xlsx')
xdf6 = pd.read_excel('xdata6.xlsx')
ydf3 = pd.read_excel('ydata3.xlsx')
ydf4 = pd.read_excel('ydata4.xlsx')
ydf5 = pd.read_excel('ydata5.xlsx')
ydf6 = pd.read_excel('ydata6.xlsx')


xts3 = xdf3['#data']
yts3 = ydf3['#data']
xts4 = xdf4['#data']
yts4 = ydf4['#data']
xts5 = xdf5['#data']
yts5 = ydf5['#data']
xts6 = xdf6['#data']
yts6 = ydf6['#data']

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts1[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts1[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts1[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts1[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts3[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

# %%
import matplotlib.pyplot as plt
from scipy import stats

predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts3[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts4[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts4[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts4[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts4[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(0,100):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts4[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [1.0814197e-06]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts5[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts5[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts5[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts5[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)


for i in range(0,100):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts5[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [3.0931747e-06]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15132/2698070687.py in <module>
#      56
#      57 fig, ax = plt.subplots()
# ---> 58 ax.stem(xdata,predict, use_line_collection=True)
#      59 plt.show()
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in stem(self, linefmt, markerfmt, basefmt, bottom, label, use_line_collection, orientation, *args)
#    2871                 linestyle = rcParams['lines.linestyle']
#    2872             xlines = self.vlines if orientation == "vertical" else self.hlines
# -> 2873             stemlines = xlines(
#    2874                 locs, bottom, heads,
#    2875                 colors=linecolor, linestyles=linestyle, label="_nolegend_")
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1113         masked_verts[:, 0, 1] = ymin
#    1114         masked_verts[:, 1, 0] = x
# -> 1115         masked_verts[:, 1, 1] = ymax
#    1116
#    1117         lines = mcoll.LineCollection(masked_verts, colors=colors,
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\ma\core.py in __setitem__(self, indx, value)
#    3378         if _mask is nomask:
#    3379             # Set the data, then the mask
# -> 3380             _data[indx] = dval
#    3381             if mval is not nomask:
#    3382                 _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (200) into shape (100)

# %%
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15132/3945230642.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.stem(xdata,predict, use_line_collection=True)
#       3 plt.show()
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in stem(self, linefmt, markerfmt, basefmt, bottom, label, use_line_collection, orientation, *args)
#    2871                 linestyle = rcParams['lines.linestyle']
#    2872             xlines = self.vlines if orientation == "vertical" else self.hlines
# -> 2873             stemlines = xlines(
#    2874                 locs, bottom, heads,
#    2875                 colors=linecolor, linestyles=linestyle, label="_nolegend_")
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1113         masked_verts[:, 0, 1] = ymin
#    1114         masked_verts[:, 1, 0] = x
# -> 1115         masked_verts[:, 1, 1] = ymax
#    1116
#    1117         lines = mcoll.LineCollection(masked_verts, colors=colors,
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\ma\core.py in __setitem__(self, indx, value)
#    3378         if _mask is nomask:
#    3379             # Set the data, then the mask
# -> 3380             _data[indx] = dval
#    3381             if mval is not nomask:
#    3382                 _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (200) into shape (100)

# %%
x = [] # train
y = [] # test (answer)

# %%
plt.plot(yts5[100:200])
xdata = np.arange(100,200,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts6[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts6[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts6[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts6[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(0,100):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts6[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [2.0132702e-06]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        x.append(tmpX[i:i+10])
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))

m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)
# Out:
# C:\Users\yukin\AppData\Local\Temp/ipykernel_12132/3989391290.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x = np.array(x)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12132/3989391290.py in <module>
#      12 x = np.array(x)
#      13 y = np.array(y)
# ---> 14 x = x.reshape((x.shape[0], x.shape[1], 1))
#      15 y = y.reshape((y.shape[0], y.shape[1], 1))
#      16
#
# IndexError: tuple index out of range

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        x.append(tmpX[i:i+10])
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))

m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)
# Out:
# C:\Users\yukin\AppData\Local\Temp/ipykernel_12132/3989391290.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x = np.array(x)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12132/3989391290.py in <module>
#      12 x = np.array(x)
#      13 y = np.array(y)
# ---> 14 x = x.reshape((x.shape[0], x.shape[1], 1))
#      15 y = y.reshape((y.shape[0], y.shape[1], 1))
#      16
#
# IndexError: tuple index out of range

# %%
predict=[]
for i in range(750,990):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[750:990])
xdata = np.arange(750,990,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts4[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts4[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts4[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts4[760:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,990):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts4[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [0.00016445]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts5[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts5[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts5[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts5[760:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,990):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts5[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [6.0750966e-07]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts6[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts6[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts5[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts6[760:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,990):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts6[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [0.00262209]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts1[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts1[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts1[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts1[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts1[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,1000):
    input = np.array(xts1[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts1[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [0.00173204]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anakonda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1001 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11604/1023444538.py in <module>
#      51     yhat = m.predict(input)
#      52     yhat = yhat.ravel()
# ---> 53     yhat = yhat - yts1[i+10]
#      54     predict.append(yhat)
#      55
#
# D:\anakonda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# D:\anakonda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# D:\anakonda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1001

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts2[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts2[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts2[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts2[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts1[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,1000):
    input = np.array(xts2[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts2[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [3.1891343e-09]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anakonda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1001 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11604/2219566924.py in <module>
#      51     yhat = m.predict(input)
#      52     yhat = yhat.ravel()
# ---> 53     yhat = yhat - yts2[i+10]
#      54     predict.append(yhat)
#      55
#
# D:\anakonda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# D:\anakonda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# D:\anakonda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1001

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts1[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts1[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts1[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts6[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts1[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(750,1000):
    input = np.array(xts1[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts1[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
